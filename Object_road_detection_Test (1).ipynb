# %% [markdown]
# Voilà le Tuto
# https://medium.com/analytics-vidhya/object-detection-with-yolo-aa2dfab21d56

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!git clone 'https://ElencheZetetique@bitbucket.org/ElencheZetetique/rtod.git' '/content/drive/My Drive/yolo_road_model_Training/Testing'

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training/Testing/Tools
# Out:
# /content/drive/My Drive/yolo_road_model_Training/Testing/Tools

# %%
# !ls
# Out:
# prepare.py  test.py

# %%
# !apt-get install libmagic-dev
# !pip install python-magic
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libmagic-mgc libmagic1
# Suggested packages:
#   file
# The following NEW packages will be installed:
#   libmagic-dev libmagic-mgc libmagic1
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 332 kB of archives.
# After this operation, 5,552 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-dev amd64 1:5.32-2ubuntu0.4 [79.7 kB]
# Fetched 332 kB in 0s (3,624 kB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 160772 files and directories currently installed.)
# ...

# %%
#!python3 test.py -d /path/to/Model -is /path/to/folder/with/images
# %cd /content/drive/My Drive/yolo_road_model_Training/Testing/Tools
# Dans un dossier, que j'ai nommé FilesToTest, il faut laisser seulement un fichier weights, .names, .cfg
#!python3 test.py -d '/content/drive/My Drive/yolo_road_model_Training/backup' -is '/content/drive/My Drive/yolo_road_model_Training/road_data'
# !python3 test.py -d '/content/drive/My Drive/yolo_road_model_Training/FilesToTest' -is '/content/drive/My Drive/yolo_road_model_Training/road_data'
# Out:
# /content/drive/My Drive/yolo_road_model_Training/Testing/Tools
# 100% 1218/1218 [25:50<00:00,  1.27s/it]

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training/darknet
! make clean
# !make
#!./darknet/darknet detector map /content/drive/My\ Drive/yolo_road_model_Training/road_data/labelled_data.data /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/yolov2_road.cfg /content/drive/My\ Drive/yolo_road_model_Training/backup/yolov2_road_$i.weights -points 0 >> /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/output$i.txt
# Out:
# /content/drive/My Drive/yolo_road_model_Training/darknet
# ...

# %%
#test accuracy
# %cd /content/drive/My Drive/yolo_road_model_Training/FilesToTest
#!ls
# !bash /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/get_mAP.sh
# Out:
# /content/drive/My Drive/yolo_road_model_Training/FilesToTest
# /content/drive/My Drive/yolo_road_model_Training/FilesToTest/get_mAP.sh: line 6: /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/output1000.txt: No such file or directory
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training
# !./darknet/darknet detector map /content/drive/My\ Drive/yolo_road_model_Training/road_data/labelled_data.data /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/yolov2_road.cfg /content/drive/My\ Drive/yolo_road_model_Training/backup/yolov2_road_train_last.weights -points 0 >> /content/drive/My\ Drive/yolo_road_model_Training/FilesToTest/out.txt
# Out:
# /content/drive/My Drive/yolo_road_model_Training
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training/Testing/Tools
# !python3 prepare.py -msy -s '/content/drive/My Drive/yolo_road_model_Training/FilesToTest' -d '/content/drive/My Drive/yolo_road_model_Training/Testing/Results/'
# Out:
# /content/drive/My Drive/yolo_road_model_Training/Testing/Tools
# Traceback (most recent call last):
#   File "prepare.py", line 9, in <module>
#     import magic
# ModuleNotFoundError: No module named 'magic'
