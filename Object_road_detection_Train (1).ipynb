# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#create a folder in Google Drive named yolo_road_model_Training
#content of the folder yolo_road_model_Training
# !ls '/content/drive/MyDrive/yolo_road_model_Training'
# Out:
# ls: cannot access '/content/drive/MyDrive/yolo_road_model_Training': No such file or directory

# %%
#We can upload directly all the images in the directery in a file called "road_data" inside yolo_road_model_Training
#ou bien upload road_data.zip in the folder yolo_road_model_Training. Then, upzip the zip by the following command.
#!unzip '/content/drive/My Drive/yolo_road_model_Training/road_data.zip' -d '/content/drive/My Drive/yolo_road_model_Training/'

# %%
# Create a new folder called darknet inside yolo_road_model_Training
# clone darknet repository 
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_road_model_Training/darknet'
# Out:
# Cloning into '/content/drive/My Drive/yolo_road_model_Training/darknet'...
# remote: Enumerating objects: 15035, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 15035 (delta 11), reused 18 (delta 8), pack-reused 15002
# Receiving objects: 100% (15035/15035), 13.44 MiB | 6.18 MiB/s, done.
# Resolving deltas: 100% (10210/10210), done.
# Checking out files: 100% (2028/2028), done.

# %%
# Accès au dossier darknet pour la compilation
# %cd /content/drive/MyDrive/yolo_road_model_Training/darknet
# Out:
# /content/drive/MyDrive/yolo_road_model_Training/darknet

# %%
# content of darknet folder
# !ls
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# Compilation
# We should modify the content of the file "makefile"
# GPU=1
# CUDNN=1
# OPENCV=1
# Not forget to turn GPU
#***************
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DCUDNN -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘get_workspace_size’:
# ./src/convolutional_layer.c:91:9: warning: implicit declaration of function ‘cudnnGetConvolutionForwardWorkspaceSize’ [-Wimplicit-function-declaration]
#          cudnnGetConvolutionForwardWorkspaceSize(cudnn_handle(),
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:91:49: warning: implicit declaration of function ‘cudnn_handle’ [-Wimplicit-function-declaration]
#          cudnnGetConvolutionForwardWorkspaceSize(cudnn_handle(),
#                                                  ^~~~~~~~~~~~
# ./src/convolutional_layer.c:92:18: error: ‘layer {aka struct layer}’ has no member named ‘srcTensorDesc’
#                  l.srcTensorDesc,
#                   ^
# ...

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training
# Out:
# /content/drive/My Drive/yolo_road_model_Training

# %%
# download the files from the following link
# https://github.com/jakkcoder/training_yolo_custom_object_detection_files
# execute creating-files-data-and-name.py
# 
# !python road_data/creating-files-data-and-name.py

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training/road_data
# Out:
# /content/drive/My Drive/yolo_road_model_Training/road_data

# %%
# !ls
# Out:
#  100.jpg        240.jpg   381.txt   521.jpg
#  100.txt        240.txt   382.jpg   521.txt
#  101.jpg        241.jpg   382.txt   522.jpg
#  101.txt        241.txt   383.jpg   522.txt
#  102.jpg        242.jpg   383.txt   523.jpg
#  102.txt        242.txt   384.jpg   523.txt
#  103.jpg        243.jpg   384.txt   524.jpg
#  103.txt        243.txt   385.jpg   524.txt
#  104.jpg        244.jpg   385.txt   525.jpg
#  104.txt        244.txt   386.jpg   525.txt
#  105.jpg        245.jpg   386.txt   527.jpg
#  105.txt        245.txt   387.jpg   527.txt
#  106.jpg        247.jpg   387.txt   528.jpg
#  106.txt        247.txt   388.jpg   528.txt
#  107.jpg        248.jpg   388.txt   529.jpg
#  107.txt        248.txt   389.jpg   529.txt
#  108.jpg        249.jpg   389.txt   52.jpg
#  108.txt        249.txt   38.jpg    52.txt
#  109.jpg        24.jpg	  38.txt    530.jpg
#  109.txt        24.txt	  390.jpg   530.txt
#  10.jpg         250.jpg   390.txt   531.jpg
# ...

# %%
# %cd /content/drive/My Drive/yolo_road_model_Training
# Out:
# /content/drive/My Drive/yolo_road_model_Training

# %%
# !python road_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
#Créer un dossier road_weight dans le dossier yolo_road_model_Training. Puis, y importer le fichier darknet53.conv.74.
# !darknet/darknet detector train road_data/labelled_data.data darknet/cfg/yolov2_road_train.cfg road_weight/darknet53.conv.74 -dont_show
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.750223), count: 2, class_loss = 0.255782, iou_loss = 0.442003, total_loss = 0.697784
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.049163, iou_loss = 0.000000, total_loss = 0.049163
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.765807), count: 1, class_loss = 1.186243, iou_loss = 0.151312, total_loss = 1.337555
#  total_bbox = 471239, rewritten_bbox = 0.604152 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.795675), count: 2, class_loss = 1.139719, iou_loss = 0.288882, total_loss = 1.428601
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000063, iou_loss = 0.000000, total_loss = 0.000063
# ...
